# %%
from Annotation_helper import *

# %%
transactions = load_transactions("../../Data/structured_data\Transactions.csv")
permissions = load_permissions("../../Data/structured_data\permissions.csv")

# %%
permissions[permissions["ID"] == "897-3-18"]
# Out:
#     Unnamed: 0        ID  Permissie  Inventarisnummer  Scan  Plaats  \
# 71          71  897-3-18         18               897     3  Cochin
#
#          Datum BezitterVoornaam BezitterTussen BezitterAchternaam  ...  \
# 71  1770-10-12           Philip            NaN          Philipsz:  ...
#
#    BezitterEtniciteit BezitterStatus SlaafNaamNieuw SlaafNaamOrigineel  \
# 71                NaN        Vrijman      Zeptember                NaN
#
#    SlaafKaste SlaafGender Opmerking Betaling Door[Kantlijn] Entry-ID
# 71        NaN           m       NaN     Enz:      Hem selfs       71
#
# [1 rows x 24 columns]

# %%
per_to_trans = {
                "BezitterVoornaam" : ("KoperVoornaam", 2),
                "BezitterTussen": ("KoperTussen", 1),
                "BezitterAchternaam" : ("KoperAchternaam", 2),
                "BezitterGender" : ("KoperGender", 2),
                "SlaafNaamNieuw" : ("SlaafNaamNieuw", 2),
                "BezitterBeroep" : ("KoperBeroep", 1),
                "BezitterStatus" : ("KoperStatus", 1),
                "SlaafGender" : ("SlaafGender", 1),
                "Datum" : ("Datum", 1),
                "BezitterWerkplek" : ("KoperWerkplek", 1),
                "SlaafKaste" : ("SlaafKaste", 1)
}

# %%
a = Annotator(permissions, transactions, per_to_trans, "Matches/Bas3.csv")
a.annotate()
# Out:
# Query:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Datum</th>
#       <th>KoperVoornaam</th>
#       <th>KoperTussen</th>
#       <th>KoperAchternaam</th>
#       <th>KoperGender</th>
#       <th>KoperBeroep</th>
#       <th>KoperWerkplek</th>
#       <th>KoperStatus</th>
#       <th>SlaafNaamNieuw</th>
#       <th>SlaafKaste</th>
#       <th>SlaafGender</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1771-02-01</td>
#       <td>Samuel</td>
#       <td>NaN</td>
#       <td>Bok</td>
#       <td>m</td>
#       <td>Koopman</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Salomon</td>
#       <td>NaN</td>
#       <td>m</td>
#     </tr>
#   </tbody>
# </table>
# Possible matches:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>KoperVoornaam</th>
#       <th>KoperTussen</th>
#       <th>KoperAchternaam</th>
#       <th>KoperGender</th>
#       <th>SlaafNaamNieuw</th>
#       <th>KoperBeroep</th>
#       <th>KoperStatus</th>
#       <th>SlaafGender</th>
#       <th>Datum</th>
#       <th>KoperWerkplek</th>
#       <th>SlaafKaste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4824</th>
#       <td>Carel</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>NaN</td>
#       <td>Korporaal</td>
#       <td>VOC</td>
#       <td>m</td>
#       <td>1791-01-26</td>
#       <td>NaN</td>
#       <td>Poelia</td>
#     </tr>
#     <tr>
#       <th>3203</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>Anthonie</td>
#       <td>NaN</td>
#       <td>Koning van Koetsiem</td>
#       <td>m</td>
#       <td>1794-11-13</td>
#       <td>NaN</td>
#       <td>Kaffer</td>
#     </tr>
#     <tr>
#       <th>4590</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Breekpot</td>
#       <td>m</td>
#       <td>NaN</td>
#       <td>Boekhouder en [...]</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Poelia</td>
#     </tr>
#     <tr>
#       <th>6964</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>September</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>1789-09-[...]</td>
#       <td>NaN</td>
#       <td>Oladen Heiden</td>
#     </tr>
#     <tr>
#       <th>4311</th>
#       <td>Daniel</td>
#       <td>NaN</td>
#       <td>Bakker</td>
#       <td>m</td>
#       <td>Damon</td>
#       <td>Corporaal</td>
#       <td>VOC</td>
#       <td>m</td>
#       <td>1771-05-23</td>
#       <td>NaN</td>
#       <td>Oeladda</td>
#     </tr>
#     <tr>
#       <th>3316</th>
#       <td>Mahamadoesen</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>Kamben</td>
#       <td>NaN</td>
#       <td>Woonagtig te Kalwettij</td>
#       <td>m</td>
#       <td>1794-04-02</td>
#       <td>NaN</td>
#       <td>Parea Heiden</td>
#     </tr>
#     <tr>
#       <th>5547</th>
#       <td>Johannes</td>
#       <td>NaN</td>
#       <td>Bos</td>
#       <td>m</td>
#       <td>NaN</td>
#       <td>Boekhouder</td>
#       <td>VOC</td>
#       <td>m</td>
#       <td>1776-02-27</td>
#       <td>Cochin</td>
#       <td>Chego</td>
#     </tr>
#     <tr>
#       <th>7128</th>
#       <td>Lebbe</td>
#       <td>NaN</td>
#       <td>Bapo</td>
#       <td>m</td>
#       <td>Damon</td>
#       <td>NaN</td>
#       <td>Woonagtig te Kalwettij</td>
#       <td>m</td>
#       <td>1793-10-01</td>
#       <td>NaN</td>
#       <td>Parea Heiden</td>
#     </tr>
#     <tr>
#       <th>4922</th>
#       <td>Johannes</td>
#       <td>NaN</td>
#       <td>Bos</td>
#       <td>m</td>
#       <td>Damon</td>
#       <td>Oppercoopman en opperhoofd te Koilang</td>
#       <td>VOC; Thans in loco</td>
#       <td>m</td>
#       <td>1791-09-20</td>
#       <td>Koilang</td>
#       <td>Sjetti</td>
#     </tr>
#     <tr>
#       <th>2509</th>
#       <td>Benjamin</td>
#       <td>de</td>
#       <td>Brino</td>
#       <td>m</td>
#       <td>Damon</td>
#       <td>NaN</td>
#       <td>Vrijman; woonagtig te Colombo thans alhier</td>
#       <td>m</td>
#       <td>1768-12-16</td>
#       <td>NaN</td>
#       <td>Poelia</td>
#     </tr>
#     <tr>
#       <th>6990</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>August</td>
#       <td>NaN</td>
#       <td>Vrijman: woonagtig te Kalwetij</td>
#       <td>m</td>
#       <td>1789-10-01</td>
#       <td>NaN</td>
#       <td>[...] Heiden</td>
#     </tr>
#     <tr>
#       <th>3016</th>
#       <td>Karel</td>
#       <td>NaN</td>
#       <td>Bellefroi</td>
#       <td>m</td>
#       <td>Damon</td>
#       <td>Korporaal</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>1790-05-21</td>
#       <td>NaN</td>
#       <td>Kanaka Heiden</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-04822f76a436> in <module>
#       1 a = Annotator(permissions, transactions, per_to_trans, "Matches/Bas3.csv")
# ----> 2 a.annotate()
#
# ~\Dropbox\Scriptie\Thesis_code\Annotation\Annotation_helper.py in annotate(self)
#     113             print("Possible matches:")
#     114             display(HTML(m[get_n_dict_value(self.translation).values()].head(n=12).to_html()))
# --> 115             res = input("Index of most likely match: ").split(" ")
#     116             res_id = []
#     117             if res != ['']:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
