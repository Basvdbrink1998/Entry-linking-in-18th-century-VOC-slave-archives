# %%
from Annotation_helper import *

# %%
transactions = load_transactions("../../Data/structured_data\Transactions.csv")
permissions = load_permissions("../../Data/structured_data\permissions.csv")

# %%
permissions[permissions["ID"] == "897-3-18"]
# Out:
#     Unnamed: 0        ID  Permissie  Inventarisnummer  Scan  Plaats  \
# 71          71  897-3-18         18               897     3  Cochin
#
#          Datum BezitterVoornaam BezitterTussen BezitterAchternaam  ...  \
# 71  1770-10-12           Philip            NaN          Philipsz:  ...
#
#    BezitterEtniciteit BezitterStatus SlaafNaamNieuw SlaafNaamOrigineel  \
# 71                NaN        Vrijman      Zeptember                NaN
#
#    SlaafKaste SlaafGender Opmerking Betaling Door[Kantlijn] Entry-ID
# 71        NaN           m       NaN     Enz:      Hem selfs       71
#
# [1 rows x 24 columns]

# %%
per_to_trans = {
                "BezitterVoornaam" : ("KoperVoornaam", 2),
                "BezitterTussen": ("KoperTussen", 1),
                "BezitterAchternaam" : ("KoperAchternaam", 2),
                "BezitterGender" : ("KoperGender", 2),
                "SlaafNaamNieuw" : ("SlaafNaamNieuw", 2),
                "BezitterBeroep" : ("KoperBeroep", 1),
                "BezitterStatus" : ("KoperStatus", 1),
                "SlaafGender" : ("SlaafGender", 1),
                "Datum" : ("Datum", 1),
                "BezitterWerkplek" : ("KoperWerkplek", 1),
                "SlaafKaste" : ("SlaafKaste", 1)
}

# %%
a = Annotator(permissions, transactions, per_to_trans, "Matches/Bas3.csv")
a.annotate()
# Out:
# Query:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Datum</th>
#       <th>KoperVoornaam</th>
#       <th>KoperTussen</th>
#       <th>KoperAchternaam</th>
#       <th>KoperGender</th>
#       <th>KoperBeroep</th>
#       <th>KoperWerkplek</th>
#       <th>KoperStatus</th>
#       <th>SlaafNaamNieuw</th>
#       <th>SlaafKaste</th>
#       <th>SlaafGender</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1771-12-04</td>
#       <td>Rosetta</td>
#       <td>de</td>
#       <td>Zilva</td>
#       <td>v</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Vrije vrouw</td>
#       <td>Rama</td>
#       <td>NaN</td>
#       <td>m</td>
#     </tr>
#   </tbody>
# </table>
# Possible matches:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>KoperVoornaam</th>
#       <th>KoperTussen</th>
#       <th>KoperAchternaam</th>
#       <th>KoperGender</th>
#       <th>SlaafNaamNieuw</th>
#       <th>KoperBeroep</th>
#       <th>KoperStatus</th>
#       <th>SlaafGender</th>
#       <th>Datum</th>
#       <th>KoperWerkplek</th>
#       <th>SlaafKaste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4301</th>
#       <td>Rosetta</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>Bastiaan</td>
#       <td>NaN</td>
#       <td>Vrije vrouw</td>
#       <td>m</td>
#       <td>1771-05-14</td>
#       <td>NaN</td>
#       <td>Naijro</td>
#     </tr>
#     <tr>
#       <th>4302</th>
#       <td>Rosetta</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>Maria</td>
#       <td>NaN</td>
#       <td>Vrij vrouw</td>
#       <td>v</td>
#       <td>1771-05-14</td>
#       <td>NaN</td>
#       <td>Naijrichij</td>
#     </tr>
#     <tr>
#       <th>4444</th>
#       <td>Rosetta</td>
#       <td>de</td>
#       <td>Silva</td>
#       <td>v</td>
#       <td>Florentiena</td>
#       <td>NaN</td>
#       <td>Vrije vrouw</td>
#       <td>v</td>
#       <td>1771-08-24</td>
#       <td>NaN</td>
#       <td>Chegottij</td>
#     </tr>
#     <tr>
#       <th>2928</th>
#       <td>Katarina</td>
#       <td>de</td>
#       <td>Zilva</td>
#       <td>v</td>
#       <td>Maart</td>
#       <td>NaN</td>
#       <td>Weduwe van den toepas Michel de Sei</td>
#       <td>m</td>
#       <td>1790-03-14</td>
#       <td>NaN</td>
#       <td>Poelia Heiden</td>
#     </tr>
#     <tr>
#       <th>2858</th>
#       <td>Katji</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>Damon</td>
#       <td>NaN</td>
#       <td>Vrije vrouw</td>
#       <td>m</td>
#       <td>1774-08-05</td>
#       <td>NaN</td>
#       <td>Polia</td>
#     </tr>
#     <tr>
#       <th>3906</th>
#       <td>Leonora</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>Filander</td>
#       <td>NaN</td>
#       <td>Vrij vrouw</td>
#       <td>m</td>
#       <td>1760-12-09</td>
#       <td>NaN</td>
#       <td>moor</td>
#     </tr>
#     <tr>
#       <th>2637</th>
#       <td>Katjij</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>Januarij</td>
#       <td>NaN</td>
#       <td>Vrijvrouw</td>
#       <td>m</td>
#       <td>1773-12-28</td>
#       <td>NaN</td>
#       <td>Poel[…]</td>
#     </tr>
#     <tr>
#       <th>4436</th>
#       <td>Malola</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>September</td>
#       <td>NaN</td>
#       <td>Vrije vrouw</td>
#       <td>m</td>
#       <td>1771-08-17</td>
#       <td>NaN</td>
#       <td>Namboebettoea</td>
#     </tr>
#     <tr>
#       <th>3215</th>
#       <td>Kandoemma</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>Datan</td>
#       <td>NaN</td>
#       <td>Weduwe van den oosterschen kapitain Bapo Sali</td>
#       <td>m</td>
#       <td>1793-12-09</td>
#       <td>NaN</td>
#       <td>Moor</td>
#     </tr>
#     <tr>
#       <th>3332</th>
#       <td>Catrina</td>
#       <td>de</td>
#       <td>Zilva</td>
#       <td>v</td>
#       <td>Vrijdag</td>
#       <td>NaN</td>
#       <td>Weduwe van den toepas Michel de Sa woonagtig te Baipien</td>
#       <td>m</td>
#       <td>1794-04-24</td>
#       <td>NaN</td>
#       <td>Sawalam Heiden</td>
#     </tr>
#     <tr>
#       <th>7190</th>
#       <td>Kandoemma</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>Dapat</td>
#       <td>NaN</td>
#       <td>Wedewe van den Oostersche Kapitain Bapa Sali: woonachtig binnen deeze stad</td>
#       <td>m</td>
#       <td>1793-12-07</td>
#       <td>NaN</td>
#       <td>Sjego Heiden</td>
#     </tr>
#     <tr>
#       <th>5007</th>
#       <td>Kandoema</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>Maart</td>
#       <td>NaN</td>
#       <td>Weduwe van den Oostersche Kap:n Bapa Sali; Woonagtig binnen dese stad</td>
#       <td>m</td>
#       <td>1793-04-04</td>
#       <td>NaN</td>
#       <td>Moors</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-04822f76a436> in <module>
#       1 a = Annotator(permissions, transactions, per_to_trans, "Matches/Bas3.csv")
# ----> 2 a.annotate()
#
# E:\UvA\Scriptie\Thesis_code\Annotation\Annotation_helper.py in annotate(self)
#     113             print("Possible matches:")
#     114             display(HTML(m[get_n_dict_value(self.translation).values()].head(n=12).to_html()))
# --> 115             res = input("Index of most likely match: ").split(" ")
#     116             res_id = []
#     117             if res != ['']:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
