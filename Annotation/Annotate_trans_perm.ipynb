# %%
from Annotation_helper import *

# %%
data_folder = "../../Data"
structured_data_folder = data_folder + "/structured_data"
matches = structured_data_folder + "/Matches/Bas3.csv"

# %%
transactions = load_transactions("../../Data/structured_data\Transactions.csv")
permissions = load_permissions("../../Data/structured_data\permissions.csv")

# %%
permissions[permissions["ID"] == "897-3-18"]
# Out:
#     Unnamed: 0        ID  Permissie  Inventarisnummer  Scan  Plaats  \
# 71          71  897-3-18         18               897     3  Cochin
#
#          Datum BezitterVoornaam BezitterTussen BezitterAchternaam  ...  \
# 71  1770-10-12           Philip            NaN          Philipsz:  ...
#
#    BezitterEtniciteit BezitterStatus SlaafNaamNieuw SlaafNaamOrigineel  \
# 71                NaN        Vrijman      Zeptember                NaN
#
#    SlaafKaste SlaafGender Opmerking Betaling Door[Kantlijn] Entry-ID
# 71        NaN           m       NaN     Enz:      Hem selfs       71
#
# [1 rows x 24 columns]

# %%
per_to_trans = {
                "BezitterVoornaam" : ("KoperVoornaam", 2),
                "BezitterTussen": ("KoperTussen", 1),
                "BezitterAchternaam" : ("KoperAchternaam", 2),
                "BezitterGender" : ("KoperGender", 2),
                "SlaafNaamNieuw" : ("SlaafNaamNieuw", 2),
                "BezitterBeroep" : ("KoperBeroep", 1),
                "BezitterStatus" : ("KoperStatus", 1),
                "SlaafGender" : ("SlaafGender", 1),
                "Datum" : ("Datum", 1),
                "BezitterWerkplek" : ("KoperWerkplek", 1),
                "SlaafKaste" : ("SlaafKaste", 1)
}

# %%
a = Annotator(permissions, transactions, per_to_trans, matches)
a.annotate()
# Out:
# Query:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Datum</th>
#       <th>KoperVoornaam</th>
#       <th>KoperTussen</th>
#       <th>KoperAchternaam</th>
#       <th>KoperGender</th>
#       <th>KoperBeroep</th>
#       <th>KoperWerkplek</th>
#       <th>KoperStatus</th>
#       <th>SlaafNaamNieuw</th>
#       <th>SlaafKaste</th>
#       <th>SlaafGender</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1772-02-25</td>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Gesaghebber</td>
#       <td>Smal schip De Verwagting</td>
#       <td>NaN</td>
#       <td>Regina</td>
#       <td>NaN</td>
#       <td>v</td>
#     </tr>
#   </tbody>
# </table>
# Possible matches:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>KoperVoornaam</th>
#       <th>KoperTussen</th>
#       <th>KoperAchternaam</th>
#       <th>KoperGender</th>
#       <th>SlaafNaamNieuw</th>
#       <th>KoperBeroep</th>
#       <th>KoperStatus</th>
#       <th>SlaafGender</th>
#       <th>Datum</th>
#       <th>KoperWerkplek</th>
#       <th>SlaafKaste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4005</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Florentina</td>
#       <td>Boodsman</td>
#       <td>VOC</td>
#       <td>v</td>
#       <td>1770-05-12</td>
#       <td>NaN</td>
#       <td>Bettuatij</td>
#     </tr>
#     <tr>
#       <th>6650</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Meijer</td>
#       <td>m</td>
#       <td>Regina</td>
#       <td>Kannonier</td>
#       <td>VOC</td>
#       <td>v</td>
#       <td>1787-02-21</td>
#       <td>NaN</td>
#       <td>Poelijie</td>
#     </tr>
#     <tr>
#       <th>4210</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Abrella</td>
#       <td>Boodsman</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>1770-09-20</td>
#       <td>NaN</td>
#       <td>Poelitjij</td>
#     </tr>
#     <tr>
#       <th>4209</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Lisarda</td>
#       <td>Boodsman</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>1770-09-20</td>
#       <td>NaN</td>
#       <td>Canacattij</td>
#     </tr>
#     <tr>
#       <th>4441</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>m</td>
#       <td>NaN</td>
#       <td>Boodsman</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Bettoertij</td>
#     </tr>
#     <tr>
#       <th>1665</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Amelia</td>
#       <td>Boodsman</td>
#       <td>VOC</td>
#       <td>v</td>
#       <td>1764-12-05</td>
#       <td>Cochin</td>
#       <td>Chegottij</td>
#     </tr>
#     <tr>
#       <th>2074</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Filida</td>
#       <td>Boodsman</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>1765-11-13</td>
#       <td>NaN</td>
#       <td>Bettuatij</td>
#     </tr>
#     <tr>
#       <th>5433</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Estra</td>
#       <td>Boodsman</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>1775-06-09</td>
#       <td>NaN</td>
#       <td>Kanakatij</td>
#     </tr>
#     <tr>
#       <th>4497</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Tiadoza</td>
#       <td>Boodsman</td>
#       <td>VOC</td>
#       <td>v</td>
#       <td>1772-09-03</td>
#       <td>Cochin</td>
#       <td>Bettua</td>
#     </tr>
#     <tr>
#       <th>4529</th>
#       <td>Jan</td>
#       <td>NaN</td>
#       <td>Fernando</td>
#       <td>m</td>
#       <td>Regina</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>v</td>
#       <td>1772-10-22</td>
#       <td>NaN</td>
#       <td>Poelichij</td>
#     </tr>
#     <tr>
#       <th>2657</th>
#       <td>Johan</td>
#       <td>NaN</td>
#       <td>Fernando</td>
#       <td>m</td>
#       <td>Regina</td>
#       <td>NaN</td>
#       <td>Vrijman</td>
#       <td>v</td>
#       <td>1774-01-17</td>
#       <td>NaN</td>
#       <td>Bettoeatij</td>
#     </tr>
#     <tr>
#       <th>1964</th>
#       <td>Christiaan</td>
#       <td>NaN</td>
#       <td>Hendel</td>
#       <td>m</td>
#       <td>Calistra</td>
#       <td>Boodsman</td>
#       <td>VOC</td>
#       <td>v</td>
#       <td>1765-06-02</td>
#       <td>Cochin</td>
#       <td>Poelitie</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e9a3e09ccaad> in <module>
#       1 a = Annotator(permissions, transactions, per_to_trans, matches)
# ----> 2 a.annotate()
#
# E:\UvA\Scriptie\Thesis_code\Annotation\Annotation_helper.py in annotate(self)
#     123             print("Possible matches:")
#     124             display(HTML(m[get_n_dict_value(self.translation).values()].head(n=12).to_html()))
# --> 125             res = input("Index of most likely match: ").split(" ")
#     126             res_id = []
#     127             if res != ['']:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
